# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-13***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-13***
# <br>
#
# ***@Title : Dataframe operations***

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ***Problem 17:- Append and then delete new row to given dataframe***

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(exam_data , index=labels)

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# **appending row**

# %%
df.loc['k'] = [1, 'Suresh', 'yes', 15.5]

# %%
df
# Out:
#         name   score attempts qualify
# a  Anastasia    12.5        1     yes
# b       Dima     9.0        3      no
# c  Katherine    16.5        2     yes
# d      James     NaN        3      no
# e      Emily     9.0        2      no
# f    Michael    20.0        3     yes
# g    Matthew    14.5        1     yes
# h      Laura     NaN        1      no
# i      Kevin     8.0        2      no
# j      Jonas    19.0        1     yes
# k          1  Suresh      yes    15.5

# %% [markdown]
# **deleting row**

# %%
df = df.drop('k')

# %%
df
# Out:
#         name score attempts qualify
# a  Anastasia  12.5        1     yes
# b       Dima   9.0        3      no
# c  Katherine  16.5        2     yes
# d      James   NaN        3      no
# e      Emily   9.0        2      no
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# j      Jonas  19.0        1     yes

# %% [markdown]
# ***Problem 18:- Sort dataframe in ascending and descending order***

# %% [markdown]
# **Sort in ascending order by name**

# %%
df = df.sort_values(by ='name' )

# %%
df
# Out:
#         name score attempts qualify
# a  Anastasia  12.5        1     yes
# b       Dima   9.0        3      no
# e      Emily   9.0        2      no
# d      James   NaN        3      no
# j      Jonas  19.0        1     yes
# c  Katherine  16.5        2     yes
# i      Kevin   8.0        2      no
# h      Laura   NaN        1      no
# g    Matthew  14.5        1     yes
# f    Michael  20.0        3     yes

# %% [markdown]
# **sort in descending order by score**

# %%
df = df.sort_values(by ='score', ascending=False)

# %%
df
# Out:
#         name score attempts qualify
# f    Michael  20.0        3     yes
# j      Jonas  19.0        1     yes
# c  Katherine  16.5        2     yes
# g    Matthew  14.5        1     yes
# a  Anastasia  12.5        1     yes
# b       Dima   9.0        3      no
# e      Emily   9.0        2      no
# i      Kevin   8.0        2      no
# d      James   NaN        3      no
# h      Laura   NaN        1      no

# %% [markdown]
# ***Problem 19:- Change values in columns***

# %%
df['qualify'] = df['qualify'].map({'yes': True, 'no': False})

# %%
df
# Out:
#         name score attempts  qualify
# f    Michael  20.0        3     True
# j      Jonas  19.0        1     True
# c  Katherine  16.5        2     True
# g    Matthew  14.5        1     True
# a  Anastasia  12.5        1     True
# b       Dima   9.0        3    False
# e      Emily   9.0        2    False
# i      Kevin   8.0        2    False
# d      James   NaN        3    False
# h      Laura   NaN        1    False

# %% [markdown]
# ***Problem 20:- Delete column from dataframe***

# %%
df = pd.DataFrame(exam_data , index=labels)

# %%
df.pop('attempts')
# Out:
# a    1
# b    3
# c    2
# d    3
# e    2
# f    3
# g    1
# h    1
# i    2
# j    1
# Name: attempts, dtype: int64

# %%
df
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d      James    NaN      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %% [markdown]
# ***Problem 21:- Add new coloumn to dataframe***

# %%
df = pd.DataFrame(exam_data , index=labels)

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
exam = ['GATE','GATE','GATE','CAT','GRE','GRE','GRE','GATE','CAT','GRE']

# %%
df['exam'] = exam

# %%
df
# Out:
#         name  score  attempts qualify  exam
# a  Anastasia   12.5         1     yes  GATE
# b       Dima    9.0         3      no  GATE
# c  Katherine   16.5         2     yes  GATE
# d      James    NaN         3      no   CAT
# e      Emily    9.0         2      no   GRE
# f    Michael   20.0         3     yes   GRE
# g    Matthew   14.5         1     yes   GRE
# h      Laura    NaN         1      no  GATE
# i      Kevin    8.0         2      no   CAT
# j      Jonas   19.0         1     yes   GRE
