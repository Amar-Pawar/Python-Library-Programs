# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-15***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-15***
# <br>
#
# ***@Title : Create pie chart for popularity of programing languages and create wedges***

# %%
import matplotlib.pyplot as plt

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
colors =['Red', 'Blue', 'Green','Grey','Brown','Orange']
explode = (0.1, 0, 0, 0.2, 0, 0)

# %%
plt.pie(popuratity, explode=explode, shadow=True, labels=languages, colors=colors,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Popularity of programing languages')
plt.show()
