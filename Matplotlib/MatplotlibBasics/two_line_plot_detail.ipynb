# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-14***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-14***
# <br>
#
# ***@Title : Draw two lines on same plot and give legend and add colours and width***

# %%
from matplotlib import pyplot as plt

# %%
age_x = [23,24,25,26,27,28,29,30]

# %%
py_devop = [2000,3000,3233,3500,3790,4500, 6789, 8900]
jv_devop = [1500,2200,2500,2700,3200,3800, 4700, 7000]

# %%
plt.plot(age_x,py_devop, color='b', label='Python', linewidth=2)
plt.plot(age_x,jv_devop,color='g',label='Java', linewidth=4)
plt.title("Salary cap in USD")
plt.xlabel("Ages")
plt.ylabel("salary")
plt.legend()
plt.show()
