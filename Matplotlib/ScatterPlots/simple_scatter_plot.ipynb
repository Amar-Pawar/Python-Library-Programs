# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-15***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-15***
# <br>
#
# ***@Title : Create scatter plot for random values for x and y***

# %%
import matplotlib.pyplot as plt
from pylab import randn

# %%
x_values = randn(30)
y_values = randn(30)

# %%
plt.scatter(x_values,y_values, color='blue')
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()
