# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-15***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-15***
# <br>
#
# ***@Title : Draw seaborn swarmplot from given data for bill against size***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')

# %%
sns.swarmplot(data=df, y="total_bill", x="size", size=2.5)
plt.title('Size vs total bill')
plt.xlabel('size')
plt.ylabel('Total bill')
sns.despine()
plt.show()
