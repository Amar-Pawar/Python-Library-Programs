# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-15***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-15***
# <br>
#
# ***@Title : Draw seaborn point plot for sex vs survived for given data***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
sns.pointplot(data=df, x="sex", y="survived")
plt.title('Sex and Survived of Titanic Passengers')
plt.xlabel('sex')
plt.ylabel('survived')
sns.despine()
plt.show()
