# %% [markdown]
# ***@Author: Amar Pawar***
# <br>
#
# ***@Date: 2021-07-15***
# <br>
#
# ***@Last Modified by: Amar Pawar***
# <br>
#
# ***@Last Modified time: 2021-07-15***
# <br>
#
# ***@Title : Draw seaborn plot to count decks***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
sns.countplot(data=df, x="deck")
plt.title('Number of passengers by deck ')
plt.xlabel('Deck')
plt.ylabel('Number of Passengers')
sns.despine()
plt.show()
